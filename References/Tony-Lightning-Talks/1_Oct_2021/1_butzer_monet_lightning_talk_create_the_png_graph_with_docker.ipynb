# %% [markdown]
# # Doug Jaton - wants you to learn the cloud!
# # Pete Doucette wants you to learn AI/ML in the cloud!
#
# ![](https://edutech4teachers.edublogs.org/files/2016/10/cloud-computing-halloween-1onw7de-e1477068194892.jpg)

# %%
! TZ=CST6CDT date #- the beginning

import time
start_time = time.time()
# Out:
# Tue Oct 19 11:45:30 CDT 2021

# %% [markdown]
# # soap box --> CLOUD SKILLS SHOULD BE ENCOURAGED AT EROS
#
# ## This year I completed the following MANDATORY TRAINING CLASSES:
# - Code of Business Conduct Ethics;
# - Working from Home Best Practices;
# - IT Security Awareness Training;Government Export Compliance Training;
# - How to Protect Yourself Against COVID-19 and
# - Defensive Driving 2.0.
#
# that's just on the contractor side - also DOI-Learn stuff
#
# ### "Just Sayin"

# %% [markdown]
# # Sioux Falls Animation Week
#
# 1. using the monet tool to download Sentinel TCI true color images
# 2. Turning upside down images right side up
# 3. Animating jpeg and tif files with a few lines of python
# 4. In two weeks we will replace the monet tool with xarray
#
# # COGS + STAC - cloud
# # Python - Xarray - Pandas - GeoPandas and HVPLOT
# # Jupyter Notebooks
# # Git

# %%
! docker ps
# Out:
# CONTAINER ID   IMAGE     COMMAND   CREATED   STATUS    PORTS     NAMES

# %%
! docker image list | grep monet
# Out:
# tbutzer/monet-tool        latest    f352dfd1ad9c   5 weeks ago     1.55GB

# %%
#! wget https://raw.githubusercontent.com/tonybutzer/yaml-to-python/52ae046672fafba0a5ba32382c04e937dc77955e/yaml_py/example/demo.yaml

# %%
! cat demo.yaml
# Out:
# main_func:
#   def:
#     - "demo monet"
#     - display thumbnails
#     - "demo right side up sioux falls"
#     - "demo sf upside down animation"
#     - "turn it back to thomas"
#
# demo monet:
#   def:
#     - run sioux falls tci
#     - demo calendar
#     - demo thumbnails
#
# ut util fun:
#
# ut subcmd:

# %%
# %%bash
# #alias ccat='pygmentize -g'
# pygmentize -g demo.yaml
# Out:
# main_func:
#   def:
#     - "demo monet"
#     - display thumbnails
#     - "demo right side up sioux falls"
#     - "demo sf upside down animation"
#     - "turn it back to thomas"
#
# demo monet:
#   def:
#     - run sioux falls tci
#     - demo calendar
#     - demo thumbnails
#
# ut util fun:
#
# ut subcmd:

# %%
! docker image list | grep py
# Out:
# tbutzer/yaml-python       latest    13baec389f4f   2 days ago      953MB
# tbutzer/yaml-python       <none>    4cec41d6d209   3 days ago      950MB
# tbutzer/yaml-python       <none>    fae421e78bf5   4 days ago      950MB
# python                    latest    a5210955ee89   5 weeks ago     911MB
# tbutzer/et-base-python    latest    241d0025d4f0   13 months ago   1.51GB

# %%
! docker run tbutzer/yaml-python ls api
# Out:
# yaml_to_python.py

# %%
! docker run -v `pwd`:/home/host tbutzer/yaml-python python api/yaml_to_python.py ./host/demo.yaml
# Out:
# # generated from ./host/demo.yaml
# def main_func():
#     """ GENERIC HELP for main_func"""
#     print("main_func")
#     demo_monet()
#     display_thumbnails()
#     demo_right_side_up_sioux_falls()
#     demo_sf_upside_down_animation()
#     turn_it_back_to_thomas()
#
# def demo_monet():
#     """ GENERIC HELP for demo_monet"""
#     print("demo_monet")
#     run_sioux_falls_tci()
#     demo_calendar()
#     demo_thumbnails()
#
# def ut_util_fun():
#     """ GENERIC HELP for ut_util_fun"""
#     print("ut_util_fun")
#
# def ut_subcmd():
#     """ GENERIC HELP for ut_subcmd"""
#     print("ut_subcmd")
#
# def display_thumbnails():
#     """ GENERIC HELP for display_thumbnails"""
#     print("display_thumbnails")
#
#
# def demo_right_side_up_sioux_falls():
#     """ GENERIC HELP for demo_right_side_up_sioux_falls"""
#     print("demo_right_side_up_sioux_falls")
#
#
# def demo_sf_upside_down_animation():
#     """ GENERIC HELP for demo_sf_upside_down_animation"""
# ...

# %%
! docker run -v `pwd`:/home/host tbutzer/yaml-python python api/yaml_to_python.py ./host/demo.yaml > demo.py

# %%
! python3 demo.py
# Out:
# main_func
# demo_monet
# run_sioux_falls_tci
# demo_calendar
# demo_thumbnails
# display_thumbnails
# demo_right_side_up_sioux_falls
# demo_sf_upside_down_animation
# turn_it_back_to_thomas

# %%
! docker run -v `pwd`:/home/host tbutzer/yaml-python python pyan3 --help
# Out:
# Usage: pyan3 FILENAME... [--dot|--tgf|--yed]
#
# Analyse one or more Python source files and generate anapproximate call graph
# of the modules, classes and functions within them.
#
# Options:
#   -h, --help            show this help message and exit
#   --dot                 output in GraphViz dot format
#   --tgf                 output in Trivial Graph Format
#   --yed                 output in yEd GraphML Format
#   -f FILE, --file=FILE  write graph to FILE
#   -l LOG, --log=LOG     write log to LOG
#   -v, --verbose         verbose output
#   -V, --very-verbose    even more verbose output (mainly for debug)
#   -d, --defines         add edges for 'defines' relationships [default]
#   -n, --no-defines      do not add edges for 'defines' relationships
#   -u, --uses            add edges for 'uses' relationships [default]
#   -N, --no-uses         do not add edges for 'uses' relationships
#   -c, --colored         color nodes according to namespace [dot only]
# ...

# %%
! docker run -v `pwd`:/home/host tbutzer/yaml-python ./pyan3 -c --dot ./host/demo.py > demo.dot

# %%
! docker run -v `pwd`:/home/host tbutzer/yaml-python dot -Tpng ./host/demo.dot -o ./host/demo.png

# %%
from IPython.display import Image
Image(filename='./demo.png')

# %%
! TZ=CST6CDT date   # THE END


print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# Tue Oct 19 11:45:41 CDT 2021
# --- 11.005045652389526 seconds ---
